# %% [markdown]
# # YOLOv8-Pose: Pose Detection from Video
# This notebook processes an `.mp4` video and extracts human pose keypoints using YOLOv8-Pose, then generates a DataFrame with frame number, person ID, and label.

# %%
# Install Ultralytics (YOLOv8)
# !pip install -q ultralytics
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !apt-get update
# !apt-get install -y libgl1
# Out:
# Reading package lists... Done
# E: List directory /var/lib/apt/lists/partial is missing. - Acquire (13: Permission denied)
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %%
# Fix OpenCV libGL.so.1 error
# !apt-get update
# !apt-get install -y libgl1
# Out:
# Reading package lists... Done
# E: List directory /var/lib/apt/lists/partial is missing. - Acquire (13: Permission denied)
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %%
# Fix OpenCV import error by installing required system libraries
# !apt-get update -y && apt-get install -y libgl1-mesa-glx libglib2.0-0
# Out:
# Reading package lists... Done
# E: List directory /var/lib/apt/lists/partial is missing. - Acquire (13: Permission denied)

# %%
# Fix OpenCV dependency issue
# !apt-get update -y && apt-get install -y libgl1-mesa-glx libglib2.0-0
# Out:
# Reading package lists... Done
# E: List directory /var/lib/apt/lists/partial is missing. - Acquire (13: Permission denied)

# %%
# !pip install opencv-python
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !pip install opencv-python-headless  # use this if you don't need GUI windows
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 52.9 MB/s eta 0:00:00:00:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# Import necessary libraries
import cv2
import pandas as pd
from ultralytics import YOLO
from pathlib import Path
from IPython.display import display

# Load YOLOv8-Pose model
model = YOLO('yolov8n-pose.pt')  # or yolov8s-pose.pt for better accuracy
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/codespace/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.52M/6.52M [00:00<00:00, 284MB/s]

# %%
# Path to video
video_path = 'sample_video.mp4'  

# Open video
cap = cv2.VideoCapture(video_path)
frame_id = 0
results_data = []

# %%
# Process video frame by frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    results = model.predict(source=frame, save=False, verbose=False)
    poses = results[0]

    for i, keypoints in enumerate(poses.keypoints.xy):
        label = 'person'
        results_data.append({
            'frame': frame_id,
            'person_id': i,
            'label': label
        })

    frame_id += 1

cap.release()

# %%
# Create DataFrame
df = pd.DataFrame(results_data)
display(df.head())
# Out:
#    frame  person_id   label
# 0      0          0  person
# 1      0          1  person
# 2      1          0  person
# 3      2          0  person
# 4      3          0  person
